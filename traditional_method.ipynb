# %%
import sys
import numpy as np
from sklearn.svm import OneClassSVM
from sklearn.preprocessing import StandardScaler
import librosa
import numpy as np
import pandas as pd
from pyod.models.abod import ABOD
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
from sklearn.covariance import EllipticEnvelope
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from deepod.metrics import ts_metrics
from deepod.metrics import point_adjustment 
import random
import torch
sys.path.append("/home/iot/GSVDD/compaison/traditional_method/SVDD-Python")
from src.BaseSVDD import BaseSVDD
# %matplotlib inline

# %%
def load_data(dataset):
    if dataset == 0:
        train_data = np.load('../../../TranAD/processed/SWaT/train.npy')
        test_data = np.load('../../../TranAD/processed/SWaT/test.npy')
        labels = np.load('../../../TranAD/processed/SWaT/labels.npy')
    elif dataset == 1:
        train_data = np.load('/home/iot/GSVDD/TranAD/processed/SMAP/P-1_train.npy')
        test_data = np.load('/home/iot/GSVDD/TranAD/processed/SMAP/P-1_test.npy')
        labels = np.load('/home/iot/GSVDD/TranAD/processed/SMAP/P-1_labels.npy')[:, 0]
    elif dataset == 2:
        train_data = np.load('/home/iot/GSVDD/TranAD/processed/MSL/C-1_train.npy')
        test_data = np.load('/home/iot/GSVDD/TranAD/processed/MSL/C-1_test.npy')
        labels = np.load('/home/iot/GSVDD/TranAD/processed/MSL/C-1_labels.npy')[:, 0]
    return train_data, test_data, labels

# List of models to evaluate
# models = {
#     "IsolationForest": IsolationForest(),
#     "OneClassSVM": OneClassSVM(),
#     # "BaseSVDD":BaseSVDD(gamma=3,)
# }

# Results storage
results_table = []

# Repeat for 3 datasets
for dataset_idx in range(3):
    train_data, test_data, labels = load_data(dataset_idx)
    print(f"Dataset {dataset_idx}: Running experiments...")

    # Train, evaluate, and repeat 10 times for all models
    for model_name in ["IsolationForest","OneClassSVM","BaseSVDD"]:
        print(f"Running model {model_name}...")
        raw_metrics_list = []
        adj_metrics_list = []
        for run in range(10):
            print(f"Run {run + 1}/10 for {model_name}...")

            if model_name=='BaseSVDD':
                model = BaseSVDD(gamma=np.random.uniform(0.1, 5))
                model.fit(train_data)
                scores = model.get_distance(test_data)
                scores = np.array(scores)
            # Prediction and evaluation
            elif model_name=="IsolationForest":
                model = IsolationForest(random_state=42+run)
                model.fit(train_data)
                scores = model.decision_function(test_data)
            elif model_name=="OneClassSVM":
                nu_value = np.random.uniform(0.01, 0.5)
                gamma_value = np.random.uniform(0.01, 1.0)
                model = OneClassSVM(kernel='rbf', nu=nu_value, gamma=gamma_value)
                model.fit(train_data)
                scores = model.decision_function(test_data)
                
            raw_eval_metrics = ts_metrics(labels, scores)
            adjusted_metrics = ts_metrics(labels, point_adjustment(labels, scores))
            print(adjusted_metrics)
            # Collect raw and adjusted metrics
            raw_metrics_list.append([
                raw_eval_metrics[0],  # Raw AUC
                raw_eval_metrics[2],  # Raw F1
                raw_eval_metrics[3],  # Raw Precision
                raw_eval_metrics[4],  # Raw Recall
            ])
            adj_metrics_list.append([
                adjusted_metrics[0],  # Adjusted AUC
                adjusted_metrics[2],  # Adjusted F1
                adjusted_metrics[3],  # Adjusted Precision
                adjusted_metrics[4],  # Adjusted Recall
            ])

        # Calculate mean and standard deviation for both raw and adjusted metrics
        raw_metrics_array = np.array(raw_metrics_list)
        adj_metrics_array = np.array(adj_metrics_list)

        raw_means, raw_stds = np.mean(raw_metrics_array, axis=0), np.std(raw_metrics_array, axis=0)
        adj_means, adj_stds = np.mean(adj_metrics_array, axis=0), np.std(adj_metrics_array, axis=0)

        # Append the results for table format
        results_table.append([
            f"Dataset {dataset_idx}",
            model_name,
            f"{raw_means[0]:.3f} ± {raw_stds[0]:.3f}",  # Raw AUC
            f"{raw_means[1]:.3f} ± {raw_stds[1]:.3f}",  # Raw F1
            f"{raw_means[2]:.3f} ± {raw_stds[2]:.3f}",  # Raw Precision
            f"{raw_means[3]:.3f} ± {raw_stds[3]:.3f}",  # Raw Recall
            f"{adj_means[0]:.3f} ± {adj_stds[0]:.3f}",  # Adjusted AUC
            f"{adj_means[1]:.3f} ± {adj_stds[1]:.3f}",  # Adjusted F1
            f"{adj_means[2]:.3f} ± {adj_stds[2]:.3f}",  # Adjusted Precision
            f"{adj_means[3]:.3f} ± {adj_stds[3]:.3f}",  # Adjusted Recall
        ])

# Convert results to DataFrame
columns = [
    "Dataset", "Model", 
    "Raw AUC (Mean ± Std)", "Raw F1 (Mean ± Std)", 
    "Raw Precision (Mean ± Std)", "Raw Recall (Mean ± Std)",
    "Adjusted AUC (Mean ± Std)", "Adjusted F1 (Mean ± Std)", 
    "Adjusted Precision (Mean ± Std)", "Adjusted Recall (Mean ± Std)"
]
df_results = pd.DataFrame(results_table, columns=columns)

# Save results to a CSV file
df_results.to_csv("time_series_anomaly_metrics_summary_traiditional.csv", index=False)

# Display the table
print("\nResults Summary (Mean ± Std):")
print(df_results.to_string(index=False))
# Out:
# Dataset 0: Running experiments...
# Running model IsolationForest...
# Run 1/10 for IsolationForest...
# (0.4292316159905092, 0.13131975346265684, 0.2598197457942873, 0.17513513513513512, 0.5031055900621118)
# Run 2/10 for IsolationForest...
# (0.4537772559017618, 0.14421693386768566, 0.25884204597900357, 0.18816067653276955, 0.41459627329192544)
# Run 3/10 for IsolationForest...
# (0.5282239033474212, 0.2298789448499829, 0.40256116424815463, 0.41625207296849087, 0.38975155279503104)
# Run 4/10 for IsolationForest...
# (0.39095161810082757, 0.11689276571206887, 0.24250338737026683, 0.15532286212914484, 0.5527950310559007)
# Run 5/10 for IsolationForest...
# (0.4505627634333168, 0.14371110029928108, 0.2702926863554518, 0.19840116279069767, 0.42391304347826086)
# Run 6/10 for IsolationForest...
# (0.4373385178721147, 0.13236774379301197, 0.2720283533401137, 0.18359587180879958, 0.5248447204968945)
# Run 7/10 for IsolationForest...
# (0.43845659445955887, 0.134267942350686, 0.23642852744299378, 0.1621465666474322, 0.4363354037267081)
# Run 8/10 for IsolationForest...
# (0.510089959447667, 0.19308603532260488, 0.32601399408452875, 0.2733964248159832, 0.40372670807453415)
# Run 9/10 for IsolationForest...
# (0.4967325713373144, 0.1807864465144953, 0.3152197741826909, 0.27744982290436837, 0.36490683229813664)
# Run 10/10 for IsolationForest...
# (0.5109100248675347, 0.2323647066761592, 0.3793627461262828, 0.40860215053763443, 0.35403726708074534)
# Running model OneClassSVM...
# Run 1/10 for OneClassSVM...
# (0.41000347917343966, 0.12193495322414538, 0.24213062821956588, 0.15526315789473685, 0.5496894409937888)
# Run 2/10 for OneClassSVM...
# (0.41293742763604424, 0.12213128972467253, 0.2463328731058205, 0.15886588658865886, 0.5481366459627329)
# Run 3/10 for OneClassSVM...
# (0.4112055050790229, 0.12200182875145893, 0.24378107194094756, 0.15674955595026643, 0.5481366459627329)
# Run 4/10 for OneClassSVM...
# (0.40852696929772025, 0.12216338236844705, 0.23910500556141484, 0.15278377211911956, 0.5496894409937888)
# Run 5/10 for OneClassSVM...
# (0.4069969885187277, 0.12381284100384458, 0.23623286213505934, 0.1504462388440289, 0.5496894409937888)
# Run 6/10 for OneClassSVM...
# (0.40672999047504976, 0.12420807929011046, 0.23583940146874988, 0.15012722646310434, 0.5496894409937888)
# Run 7/10 for OneClassSVM...
# (0.40679807675855106, 0.12469135842192927, 0.23583940146874988, 0.15012722646310434, 0.5496894409937888)
# Run 8/10 for OneClassSVM...
# (0.4232316459342151, 0.12475809990940318, 0.254462320123346, 0.16626965221534065, 0.5419254658385093)
# Run 9/10 for OneClassSVM...
# (0.40749355497379214, 0.12322088474455085, 0.23702373521400769, 0.15108834827144688, 0.5496894409937888)
# Run 10/10 for OneClassSVM...
# (0.41853725709951006, 0.12334200965260286, 0.2509796516687254, 0.1630283325592197, 0.5450310559006211)
# Running model BaseSVDD...
# Run 1/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 33.7995 seconds
# kernel function      = rbf
# iterations           = 21
# number of samples    = 3000
# number of features   = 1
# number of SVs        = 9
# ratio of SVs         = 0.3000 %
# accuracy             = 99.7667 %
#
#
# (0.857990727432427, 0.7795549400479994, 0.8150825674961042, 1.0, 0.687888198757764)
# Run 2/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 19.1859 seconds
# kernel function      = rbf
# iterations           = 12
# number of samples    = 3000
# number of features   = 1
# number of SVs        = 2
# ratio of SVs         = 0.0667 %
# accuracy             = 99.9667 %
#
#
# (0.8522643501645477, 0.765099951479226, 0.8150825674961042, 1.0, 0.687888198757764)
# Run 3/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 24.5651 seconds
# kernel function      = rbf
# iterations           = 18
# number of samples    = 3000
# number of features   = 1
# number of SVs        = 22
# ratio of SVs         = 0.7333 %
# accuracy             = 99.4000 %
#
#
# (0.8572706526016803, 0.7793147422739105, 0.8150825674961042, 1.0, 0.687888198757764)
# Run 4/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 24.0850 seconds
# kernel function      = rbf
# iterations           = 18
# number of samples    = 3000
# number of features   = 1
# number of SVs        = 7
# ratio of SVs         = 0.2333 %
# accuracy             = 99.9000 %
#
#
# (0.8578178381785101, 0.77951493885911, 0.8150825674961042, 1.0, 0.687888198757764)
# Run 5/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 17.3374 seconds
# kernel function      = rbf
# iterations           = 12
# number of samples    = 3000
# number of features   = 1
# number of SVs        = 2
# ratio of SVs         = 0.0667 %
# accuracy             = 99.9667 %
#
#
# (0.8522643501645477, 0.765099951479226, 0.8150825674961042, 1.0, 0.687888198757764)
# Run 6/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 18.7589 seconds
# kernel function      = rbf
# iterations           = 12
# number of samples    = 3000
# number of features   = 1
# number of SVs        = 2
# ratio of SVs         = 0.0667 %
# accuracy             = 99.9667 %
#
#
# (0.8522661325279901, 0.7651003290544032, 0.8150825674961042, 1.0, 0.687888198757764)
# Run 7/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 23.7574 seconds
# kernel function      = rbf
# iterations           = 17
# number of samples    = 3000
# number of features   = 1
# number of SVs        = 15
# ratio of SVs         = 0.5000 %
# accuracy             = 99.7333 %
#
#
# (0.8577857556365462, 0.7793764405223285, 0.8150825674961042, 1.0, 0.687888198757764)
# Run 8/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 17.8242 seconds
# kernel function      = rbf
# iterations           = 12
# number of samples    = 3000
# number of features   = 1
# number of SVs        = 2
# ratio of SVs         = 0.0667 %
# accuracy             = 99.9667 %
#
#
# (0.8522643501645477, 0.765099951479226, 0.8150825674961042, 1.0, 0.687888198757764)
# Run 9/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 25.0854 seconds
# kernel function      = rbf
# iterations           = 18
# number of samples    = 3000
# number of features   = 1
# number of SVs        = 10
# ratio of SVs         = 0.3333 %
# accuracy             = 99.8000 %
#
#
# (0.8573444424481973, 0.7793180030568612, 0.8150825674961042, 1.0, 0.687888198757764)
# Run 10/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 17.9767 seconds
# kernel function      = rbf
# iterations           = 12
# number of samples    = 3000
# number of features   = 1
# number of SVs        = 2
# ratio of SVs         = 0.0667 %
# accuracy             = 99.9667 %
#
#
# (0.8522643501645477, 0.765099951479226, 0.8150825674961042, 1.0, 0.687888198757764)
# Dataset 1: Running experiments...
# Running model IsolationForest...
# Run 1/10 for IsolationForest...
# (0.9904109381279907, 0.8640608239734664, 0.882590939152688, 0.7898627243928195, 1.0)
# Run 2/10 for IsolationForest...
# (0.9906380919355917, 0.8489898771419679, 0.9121901605266878, 0.8385650224215246, 1.0)
# Run 3/10 for IsolationForest...
# (0.989649852229382, 0.8433806462439775, 0.9133039509125987, 0.8404494382022472, 1.0)
# Run 4/10 for IsolationForest...
# (0.9952945726440634, 0.9257425742574258, 0.961434596149398, 0.9257425742574258, 1.0)
# Run 5/10 for IsolationForest...
# (0.9764228824887509, 0.8271080815802815, 0.7888150062026626, 0.9407407407407408, 0.679144385026738)
# Run 6/10 for IsolationForest...
# (0.9960680675518886, 0.9245982694684796, 0.9608171014705517, 0.9245982694684796, 1.0)
# Run 7/10 for IsolationForest...
# (0.990285124562324, 0.8274549508985503, 0.9094175334496808, 0.8338907469342252, 1.0)
# Run 8/10 for IsolationForest...
# (0.9954879463710197, 0.9144254278728606, 0.9552951377303788, 0.9144254278728606, 1.0)
# Run 9/10 for IsolationForest...
# (0.9808270466764881, 0.7885891054935286, 0.8432871183056179, 0.7290448343079922, 1.0)
# Run 10/10 for IsolationForest...
# (0.9833995032259977, 0.8510618663082348, 0.8047289184839782, 0.6732673267326733, 1.0)
# Running model OneClassSVM...
# Run 1/10 for OneClassSVM...
# (0.997314828283441, 0.9656386864000464, 0.9745878371294604, 0.9504447268106735, 1.0)
# Run 2/10 for OneClassSVM...
# (0.9970311445449651, 0.9615089626210416, 0.9707931872874918, 0.9432534678436317, 1.0)
# Run 3/10 for OneClassSVM...
# (0.9985953690956384, 0.9784987720679124, 0.9829122156763801, 0.9664082687338501, 1.0)
# Run 4/10 for OneClassSVM...
# (0.9866499742513059, 0.8448944028308639, 0.8794777299101905, 0.7848898216159497, 1.0)
# Run 5/10 for OneClassSVM...
# (0.983337113485215, 0.8069875511585918, 0.8471072346819655, 0.7347740667976425, 1.0)
# Run 6/10 for OneClassSVM...
# (0.9765755822410532, 0.7309530344378441, 0.8451928599598706, 0.7318982387475538, 1.0)
# Run 7/10 for OneClassSVM...
# (0.9875809946372398, 0.8408155845435658, 0.8925964896805345, 0.8060344827586207, 1.0)
# Run 8/10 for OneClassSVM...
# (0.9962504110484303, 0.9415811669839396, 0.9758593212683158, 0.9528662420382166, 1.0)
# Run 9/10 for OneClassSVM...
# (0.9974527061636238, 0.966936921935674, 0.9771341273937181, 0.9553001277139208, 1.0)
# Run 10/10 for OneClassSVM...
# (0.9866499742513059, 0.8448944028308639, 0.8794777299101905, 0.7848898216159497, 1.0)
# Running model BaseSVDD...
# Run 1/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 21.1154 seconds
# kernel function      = rbf
# iterations           = 19
# number of samples    = 2872
# number of features   = 25
# number of SVs        = 275
# ratio of SVs         = 9.5752 %
# accuracy             = 94.3593 %
#
#
# (0.9960894386233169, 0.951724728513603, 0.959584488627195, 0.9223181257706535, 1.0)
# Run 2/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 21.1552 seconds
# kernel function      = rbf
# iterations           = 20
# number of samples    = 2872
# number of features   = 25
# number of SVs        = 205
# ratio of SVs         = 7.1379 %
# accuracy             = 95.6128 %
#
#
# (0.9960894386233169, 0.951724728513603, 0.959584488627195, 0.9223181257706535, 1.0)
# Run 3/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 21.2018 seconds
# kernel function      = rbf
# iterations           = 20
# number of samples    = 2872
# number of features   = 25
# number of SVs        = 197
# ratio of SVs         = 6.8593 %
# accuracy             = 95.5780 %
#
#
# (0.9960480752592621, 0.9513602815315279, 0.9589693674158567, 0.9211822660098522, 1.0)
# Run 4/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 19.4849 seconds
# kernel function      = rbf
# iterations           = 18
# number of samples    = 2872
# number of features   = 25
# number of SVs        = 33
# ratio of SVs         = 1.1490 %
# accuracy             = 99.4081 %
#
#
# (0.998502301526515, 0.9767327260113923, 0.9881059650649323, 0.9765013054830287, 1.0)
# Run 5/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 18.7833 seconds
# kernel function      = rbf
# iterations           = 17
# number of samples    = 2872
# number of features   = 25
# number of SVs        = 46
# ratio of SVs         = 1.6017 %
# accuracy             = 99.5125 %
#
#
# (0.9969649631624774, 0.9595147659514465, 0.973319662009022, 0.9480354879594424, 1.0)
# Run 6/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 20.5418 seconds
# kernel function      = rbf
# iterations           = 19
# number of samples    = 2872
# number of features   = 25
# number of SVs        = 171
# ratio of SVs         = 5.9540 %
# accuracy             = 95.7173 %
#
#
# (0.9962548920795362, 0.9531915485852023, 0.962052885037439, 0.9268897149938042, 1.0)
# Run 7/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 18.3645 seconds
# kernel function      = rbf
# iterations           = 17
# number of samples    = 2872
# number of features   = 25
# number of SVs        = 50
# ratio of SVs         = 1.7409 %
# accuracy             = 98.3635 %
#
#
# (0.9969649631624774, 0.9595147659514465, 0.973319662009022, 0.9480354879594424, 1.0)
# Run 8/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 18.6563 seconds
# kernel function      = rbf
# iterations           = 17
# number of samples    = 2872
# number of features   = 25
# number of SVs        = 50
# ratio of SVs         = 1.7409 %
# accuracy             = 98.3635 %
#
#
# (0.9969649631624773, 0.9595147659514465, 0.973319662009022, 0.9480354879594424, 1.0)
# Run 9/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 21.5360 seconds
# kernel function      = rbf
# iterations           = 20
# number of samples    = 2872
# number of features   = 25
# number of SVs        = 201
# ratio of SVs         = 6.9986 %
# accuracy             = 95.7869 %
#
#
# (0.9961308019873717, 0.9520900753647699, 0.9602003994716074, 0.9234567901234568, 1.0)
# Run 10/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 19.3662 seconds
# kernel function      = rbf
# iterations           = 18
# number of samples    = 2872
# number of features   = 25
# number of SVs        = 22
# ratio of SVs         = 0.7660 %
# accuracy             = 99.3036 %
#
#
# (0.9966892074021119, 0.9605456822673368, 0.9534685608815265, 0.9110840438489647, 1.0)
# Dataset 2: Running experiments...
# Running model IsolationForest...
# Run 1/10 for IsolationForest...
# (0.989797602931951, 0.8887640028474018, 0.9393889577858299, 0.8857142857142857, 1.0)
# Run 2/10 for IsolationForest...
# (0.9718361012975865, 0.7822491166273988, 0.8233683299844597, 0.6997742663656885, 1.0)
# Run 3/10 for IsolationForest...
# (0.9918611945719286, 0.9247202774324413, 0.9538411645231394, 0.9117647058823529, 1.0)
# Run 4/10 for IsolationForest...
# (0.9886337372470037, 0.9116437253673876, 0.9451169663038058, 0.8959537572254336, 1.0)
# Run 5/10 for IsolationForest...
# (0.9847789480635256, 0.8873473567015016, 0.9158000576274572, 0.8446866485013624, 1.0)
# Run 6/10 for IsolationForest...
# (0.9882622907518076, 0.8720678008118745, 0.9436784253209499, 0.8933717579250721, 1.0)
# Run 7/10 for IsolationForest...
# (0.9790174002047084, 0.8333333333333334, 0.9090859504402703, 0.8333333333333334, 1.0)
# Run 8/10 for IsolationForest...
# (0.9832106184171426, 0.8438768038143689, 0.9011578395688465, 0.8201058201058201, 1.0)
# Run 9/10 for IsolationForest...
# (0.9897315679994717, 0.9121887984366762, 0.9379677877958621, 0.8831908831908832, 1.0)
# Run 10/10 for IsolationForest...
# (0.998076732591541, 0.9763330394587424, 0.9888307263263117, 0.9779179810725552, 1.0)
# Running model OneClassSVM...
# Run 1/10 for OneClassSVM...
# (0.9930580777231156, 0.9415117788487727, 0.970261045134838, 0.9422492401215805, 1.0)
# Run 2/10 for OneClassSVM...
# (0.9982913461220986, 0.9857015326592842, 0.9841219854121376, 0.96875, 1.0)
# Run 3/10 for OneClassSVM...
# (0.9908293987519398, 0.9312233718807059, 0.9523759637449517, 0.9090909090909091, 1.0)
# Run 4/10 for OneClassSVM...
# (0.9944695744048602, 0.9518695986994097, 0.9763729555714872, 0.9538461538461539, 1.0)
# Run 5/10 for OneClassSVM...
# (0.9967725426750751, 0.9741259757760046, 0.9810076600559091, 0.9627329192546584, 1.0)
# Run 6/10 for OneClassSVM...
# (0.9805774754845313, 0.8693870909629766, 0.9198763377598375, 0.8516483516483516, 1.0)
# Run 7/10 for OneClassSVM...
# (0.9985719945851355, 0.9823608881195554, 0.9935847438203596, 0.9872611464968153, 1.0)
# Run 8/10 for OneClassSVM...
# (0.9939000231122264, 0.9489506022887253, 0.9748377704856418, 0.950920245398773, 1.0)
# Run 9/10 for OneClassSVM...
# (0.9991250371446495, 0.989092026112412, 0.9935847438203596, 0.9872611464968153, 1.0)
# Run 10/10 for OneClassSVM...
# (0.9905322415557831, 0.9443291103303879, 0.9253681622009196, 0.8611111111111112, 1.0)
# Running model BaseSVDD...
# Run 1/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 7.9399 seconds
# kernel function      = rbf
# iterations           = 15
# number of samples    = 2158
# number of features   = 55
# number of SVs        = 148
# ratio of SVs         = 6.8582 %
# accuracy             = 95.5514 %
#
#
# (0.9918116683725691, 0.9064327485380117, 0.9509152574690483, 0.9064327485380117, 1.0)
# Run 2/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 7.3157 seconds
# kernel function      = rbf
# iterations           = 14
# number of samples    = 2158
# number of features   = 55
# number of SVs        = 329
# ratio of SVs         = 15.2456 %
# accuracy             = 95.1344 %
#
#
# (0.9918116683725691, 0.9064327485380117, 0.9509152574690483, 0.9064327485380117, 1.0)
# Run 3/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 7.6020 seconds
# kernel function      = rbf
# iterations           = 15
# number of samples    = 2158
# number of features   = 55
# number of SVs        = 299
# ratio of SVs         = 13.8554 %
# accuracy             = 93.6979 %
#
#
# (0.9918116683725691, 0.9064327485380117, 0.9509152574690483, 0.9064327485380117, 1.0)
# Run 4/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 6.7613 seconds
# kernel function      = rbf
# iterations           = 13
# number of samples    = 2158
# number of features   = 55
# number of SVs        = 244
# ratio of SVs         = 11.3068 %
# accuracy             = 92.9101 %
#
#
# (0.9918116683725691, 0.9064327485380117, 0.9509152574690483, 0.9064327485380117, 1.0)
# Run 5/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 8.3087 seconds
# kernel function      = rbf
# iterations           = 16
# number of samples    = 2158
# number of features   = 55
# number of SVs        = 370
# ratio of SVs         = 17.1455 %
# accuracy             = 95.1807 %
#
#
# (0.9918116683725692, 0.9064327485380117, 0.9509152574690483, 0.9064327485380117, 1.0)
# Run 6/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 6.5723 seconds
# kernel function      = rbf
# iterations           = 12
# number of samples    = 2158
# number of features   = 55
# number of SVs        = 196
# ratio of SVs         = 9.0825 %
# accuracy             = 96.1075 %
#
#
# (0.9918116683725691, 0.9064327485380117, 0.9509152574690483, 0.9064327485380117, 1.0)
# Run 7/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 6.6579 seconds
# kernel function      = rbf
# iterations           = 13
# number of samples    = 2158
# number of features   = 55
# number of SVs        = 152
# ratio of SVs         = 7.0436 %
# accuracy             = 96.6636 %
#
#
# (0.9918116683725692, 0.9064327485380117, 0.9509152574690483, 0.9064327485380117, 1.0)
# Run 8/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 9.3991 seconds
# kernel function      = rbf
# iterations           = 19
# number of samples    = 2158
# number of features   = 55
# number of SVs        = 213
# ratio of SVs         = 9.8703 %
# accuracy             = 95.1807 %
#
#
# (0.9918116683725692, 0.9064327485380117, 0.9509152574690483, 0.9064327485380117, 1.0)
# Run 9/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 7.2305 seconds
# kernel function      = rbf
# iterations           = 14
# number of samples    = 2158
# number of features   = 55
# number of SVs        = 321
# ratio of SVs         = 14.8749 %
# accuracy             = 94.0686 %
#
#
# (0.9918116683725691, 0.9064327485380117, 0.9509152574690483, 0.9064327485380117, 1.0)
# Run 10/10 for BaseSVDD...
#
#
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 9.1767 seconds
# kernel function      = rbf
# iterations           = 18
# number of samples    = 2158
# number of features   = 55
# number of SVs        = 269
# ratio of SVs         = 12.4652 %
# accuracy             = 94.6247 %
#
#
# (0.9918116683725691, 0.9064327485380117, 0.9509152574690483, 0.9064327485380117, 1.0)
#
# Results Summary (Mean ± Std):
#   Dataset           Model Raw AUC (Mean ± Std) Raw F1 (Mean ± Std) Raw Precision (Mean ± Std) Raw Recall (Mean ± Std) Adjusted AUC (Mean ± Std) Adjusted F1 (Mean ± Std) Adjusted Precision (Mean ± Std) Adjusted Recall (Mean ± Std)
# Dataset 0 IsolationForest        0.150 ± 0.006       0.228 ± 0.000              0.129 ± 0.000           1.000 ± 0.000             0.465 ± 0.042            0.296 ± 0.055                   0.244 ± 0.093                0.437 ± 0.064
# Dataset 0     OneClassSVM        0.169 ± 0.004       0.228 ± 0.000              0.129 ± 0.000           1.000 ± 0.000             0.411 ± 0.005            0.242 ± 0.006                   0.155 ± 0.005                0.548 ± 0.003
# Dataset 0        BaseSVDD        0.715 ± 0.041       0.598 ± 0.002              0.984 ± 0.012           0.429 ± 0.004             0.855 ± 0.003            0.815 ± 0.000                   1.000 ± 0.000                0.688 ± 0.000
# Dataset 1 IsolationForest        0.498 ± 0.009       0.188 ± 0.003              0.110 ± 0.004           0.657 ± 0.058             0.989 ± 0.006            0.893 ± 0.060                   0.841 ± 0.085                0.968 ± 0.096
# Dataset 1     OneClassSVM        0.443 ± 0.021       0.165 ± 0.003              0.102 ± 0.023           0.697 ± 0.250             0.991 ± 0.007            0.923 ± 0.055                   0.861 ± 0.095                1.000 ± 0.000
# Dataset 1        BaseSVDD        0.535 ± 0.046       0.218 ± 0.020              0.140 ± 0.028           0.586 ± 0.157             0.997 ± 0.001            0.966 ± 0.010                   0.935 ± 0.019                1.000 ± 0.000
# Dataset 2 IsolationForest        0.480 ± 0.006       0.243 ± 0.001              0.142 ± 0.001           0.858 ± 0.028             0.987 ± 0.007            0.926 ± 0.042                   0.865 ± 0.069                1.000 ± 0.000
# Dataset 2     OneClassSVM        0.453 ± 0.007       0.241 ± 0.000              0.137 ± 0.000           1.000 ± 0.000             0.994 ± 0.005            0.967 ± 0.025                   0.937 ± 0.046                1.000 ± 0.000
# Dataset 2        BaseSVDD        0.531 ± 0.022       0.254 ± 0.005              0.151 ± 0.005           0.808 ± 0.064             0.992 ± 0.000            0.951 ± 0.000                   0.906 ± 0.000                1.000 ± 0.000
